# %%
from colinker.colinker import Linker

# %%
cfg_dev = '../../mininet_local/config_devices_mininet_local.json'
cfg_ctrl = '../../config_controller.json'
link = Linker('LINKER', cfg_dev, cfg_ctrl)
link.setup_multiple_device()
# Out:
# Linker time step Dt set to 0.01000 seconds
# Linker time step Dt set to 0.01000 seconds
# Linker time step Dt set to 0.01000 seconds
# Linker time step Dt set to 0.01000 seconds

# %%
link.config_devices
# Out:
# {'emec_emulator': {'ip': '10.20.0.2', 'port': 5000},
#  'devices': [{'ing_id': 'poi',
#    'ing_type': 'poi',
#    'emec_id': 'POI',
#    'modbus_ip': '10.10.0.5',
#    'modbus_port': 5002,
#    'config': 'poi',
#    'linker_reg_0': 500,
#    'linker_Dt': 0.01,
#    'setpoints': [],
#    'measurements': [{'emec_prefix': 'V',
#      'min': 0.0,
#      'max': 2.0,
#      'ing_name': 'VoltageAVG',
#      'linker_reg': 0,
#      'emec_scale': 0.001,
#      'address': 372,
#      'reg_type': 'holding',
#      'slaveID': 1,
#      'type': 'int16',
#      'size': 2,
#      'format': 'AB',
#      'scale': 100,
#      'read_individual': False,
#      'emec_name': 'V_POI',
#      'linker_register': 500},
#     {'emec_name': 'p_line_POI_GRID',
#      'min': 0.0,
#      'max': 2.0,
#      'ing_name': 'ActivePower',
#      'linker_reg': 4,
#      'emec_scale': 1e-06,
#      'address': 370,
#      'reg_type': 'holding',
#      'slaveID': 1,
#      'type': 'int32',
#      'size': 4,
# ...

# %%
'p_s_ppc_LV0101' in {'p_s_ppc_LV0101': 0.0, 'q_s_ppc_LV0101': 0.0, 'p_s_ppc_LV0102': 0.0, 'q_s_ppc_LV0102': 0.0, 'p_s_ref_BESS': 0.0, 'q_s_ref_BESS': 0.0}
# Out:
# True
